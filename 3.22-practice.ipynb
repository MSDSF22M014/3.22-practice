# %%
from matplotlib import pyplot as plt
import numpy as np

students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]

fig = plt.figure()
ax = plt.subplot()

ax.bar(x = students, height = english, label = 'English', width = 0.5 )

plt.legend(loc = 'best')

# %%
from matplotlib import pyplot as plt
import numpy as np

students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]

fig = plt.figure()
ax = plt.subplot()

ax.bar(x = students, height = english, label = 'English', width = 0.5 )
ax.set_xlabel("Names of Students")
ax.set_ylabel("Marks of Students")
ax.set_xticks = students
plt.title("Distribution of Student Marks")

plt.legend(loc = 'best')

# %%
from matplotlib import pyplot as plt
import numpy as np

students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]
maths = [ 80, 59, 80, 60, 65, 60]
fig = plt.figure()
ax = plt.subplot()

ax.bar(x = students, height = english, label = 'English', width = 0.5 )
ax.bar(x = students, height = maths, label = 'Maths', width = 0.5 )

ax.set_xlabel("Names of Students")
ax.set_ylabel("Marks of Students")
ax.set_xticks = students
plt.title("Distribution of Student Marks")

plt.legend(loc = 'best')

# %%
from matplotlib import pyplot as plt
import numpy as np

students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]
maths = [ 80, 59, 80, 60, 65, 60]
fig = plt.figure()
ax = plt.subplot()

index = np.arange(len(students))
ax.bar(x = index-0.15, height = english, label = 'English', width = 0.3,align='center' )
ax.bar(x = index+0.15, height = maths, label = 'Maths', width = 0.3,align='center' )

ax.set_xlabel("Names of Students")
ax.set_ylabel("Marks of Students")
ax.set_xticks(labels = students, ticks = index, rotation = 45)
plt.title("Distribution of Student Marks")

plt.legend(loc = 'best')
plt.savefig('vbar.png')

# %%
from matplotlib import pyplot as plt
import numpy as np

students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]
maths = [ 80, 59, 80, 60, 65, 60]
fig = plt.figure()
ax = plt.subplot()

index = np.arange(len(students))
ax.bar(x = index-0.15, height = english, label = 'English', width = 0.3,align='center' )
ax.bar(x = index+0.15, height = maths, label = 'Maths', width = 0.3,align='center' )

ax.set_xlabel("Names of Students")
ax.set_ylabel("Marks of Students")
ax.set_xticks(labels = students, ticks = index, rotation = 45, ha = 'right', rotation_mode = 'anchor' )
plt.title("Distribution of Student Marks")

plt.legend(loc = 'best')
plt.savefig('vbar.png')

# %%
# creating a dataset containing list of students and their marks
students = ["Hadeed", "Maaz", "Mujahid", "Mohid", "Kamal",  "Jamal"]
english = [85, 45, 60, 70, 83, 35]
maths = [ 80, 59, 80, 60, 65, 60]

# Create figure and axes objects
fig = plt.figure()
ax = fig.add_subplot()

index = np.arange(len(students))

#Draw bar plot between names (categorical variable) and marks (numerical variable) of students
ax.barh(y=index-0.15, width=english, height=0.3, label='English')
ax.barh(y=index+0.15, width=maths, height=0.3, label='Maths')

# adding labels
ax.set_xlabel("Marks of Students")
ax.set_ylabel("Names of Students")


plt.yticks(ticks=index, labels=students, rotation_mode = 'anchor', rotation = 45)

# adding title
plt.title("Distribution of Student Marks")

plt.legend()

plt.savefig("hbar.png")

# show plot
plt.show()
